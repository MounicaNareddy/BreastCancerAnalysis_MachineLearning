# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mouni'

# %%
os.chdir('C:/Users/mouni/Desktop/Data Sets')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mouni\\Desktop\\Data Sets'

# %%
import pandas as pd
import numpy as np
data1=pd.read_csv("data.csv")
data1
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
#drop the first coulmn as this is not used for data analysis
data1=data1.drop(['id'],axis=1)

# %%
data1
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M       17.990         10.38          122.80     1001.0
# 1           M       20.570         17.77          132.90     1326.0
# 2           M       19.690         21.25          130.00     1203.0
# 3           M       11.420         20.38           77.58      386.1
# 4           M       20.290         14.34          135.10     1297.0
# 5           M       12.450         15.70           82.57      477.1
# 6           M       18.250         19.98          119.60     1040.0
# 7           M       13.710         20.83           90.20      577.9
# 8           M       13.000         21.82           87.50      519.8
# 9           M       12.460         24.04           83.97      475.9
# 10          M       16.020         23.24          102.70      797.8
# 11          M       15.780         17.89          103.60      781.0
# 12          M       19.170         24.80          132.40     1123.0
# ...

# %%
data1.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
data1['diagnosis'].replace(['M','B'],['Malignant','Benign'],inplace=True)

# %%
data1
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    Malignant       17.990         10.38          122.80     1001.0
# 1    Malignant       20.570         17.77          132.90     1326.0
# 2    Malignant       19.690         21.25          130.00     1203.0
# 3    Malignant       11.420         20.38           77.58      386.1
# 4    Malignant       20.290         14.34          135.10     1297.0
# 5    Malignant       12.450         15.70           82.57      477.1
# 6    Malignant       18.250         19.98          119.60     1040.0
# 7    Malignant       13.710         20.83           90.20      577.9
# 8    Malignant       13.000         21.82           87.50      519.8
# 9    Malignant       12.460         24.04           83.97      475.9
# 10   Malignant       16.020         23.24          102.70      797.8
# 11   Malignant       15.780         17.89          103.60      781.0
# 12   Malignant       19.170         24.80          132.40     1123.0
# ...

# %%
x=data1.loc[:,['radius_mean','area_mean','smoothness_mean']]

# %%
x
# Out:
#      radius_mean  area_mean  smoothness_mean
# 0         17.990     1001.0          0.11840
# 1         20.570     1326.0          0.08474
# 2         19.690     1203.0          0.10960
# 3         11.420      386.1          0.14250
# 4         20.290     1297.0          0.10030
# 5         12.450      477.1          0.12780
# 6         18.250     1040.0          0.09463
# 7         13.710      577.9          0.11890
# 8         13.000      519.8          0.12730
# 9         12.460      475.9          0.11860
# 10        16.020      797.8          0.08206
# 11        15.780      781.0          0.09710
# 12        19.170     1123.0          0.09740
# 13        15.850      782.7          0.08401
# 14        13.730      578.3          0.11310
# 15        14.540      658.8          0.11390
# 16        14.680      684.5          0.09867
# 17        16.130      798.8          0.11700
# 18        19.810     1260.0          0.09831
# 19        13.540      566.3          0.09779
# ...

# %%
x.describe()
# Out:
#        radius_mean    area_mean  smoothness_mean
# count   569.000000   569.000000       569.000000
# mean     14.127292   654.889104         0.096360
# std       3.524049   351.914129         0.014064
# min       6.981000   143.500000         0.052630
# 25%      11.700000   420.300000         0.086370
# 50%      13.370000   551.100000         0.095870
# 75%      15.780000   782.700000         0.105300
# max      28.110000  2501.000000         0.163400

# %%
x=data1.iloc[:,1:31]
y=data1.iloc[:,0]

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0         17.990         10.38          122.80     1001.0          0.11840
# 1         20.570         17.77          132.90     1326.0          0.08474
# 2         19.690         21.25          130.00     1203.0          0.10960
# 3         11.420         20.38           77.58      386.1          0.14250
# 4         20.290         14.34          135.10     1297.0          0.10030
# 5         12.450         15.70           82.57      477.1          0.12780
# 6         18.250         19.98          119.60     1040.0          0.09463
# 7         13.710         20.83           90.20      577.9          0.11890
# 8         13.000         21.82           87.50      519.8          0.12730
# 9         12.460         24.04           83.97      475.9          0.11860
# 10        16.020         23.24          102.70      797.8          0.08206
# ...

# %%
y
# Out:
# 0      Malignant
# 1      Malignant
# 2      Malignant
# 3      Malignant
# 4      Malignant
# 5      Malignant
# 6      Malignant
# 7      Malignant
# 8      Malignant
# 9      Malignant
# 10     Malignant
# 11     Malignant
# 12     Malignant
# 13     Malignant
# 14     Malignant
# 15     Malignant
# 16     Malignant
# 17     Malignant
# 18     Malignant
# 19        Benign
# 20        Benign
# 21        Benign
# 22     Malignant
# 23     Malignant
# 24     Malignant
# 25     Malignant
# 26     Malignant
# 27     Malignant
# 28     Malignant
# 29     Malignant
#          ...
# 539       Benign
# 540       Benign
# 541       Benign
# 542       Benign
# 543       Benign
# 544       Benign
# 545       Benign
# 546       Benign
# 547       Benign
# 548       Benign
# 549       Benign
# 550       Benign
# 551       Benign
# 552       Benign
# 553       Benign
# 554       Benign
# 555       Benign
# 556       Benign
# 557       Benign
# 558       Benign
# 559       Benign
# ...

# %%
from sklearn import preprocessing

# %% [markdown]
# minmax=preprocessing.MinMaxScaler(features_range=(0,1))
# minmax.fit(x).transform(x)

# %%
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
minmax.fit(x).transform(x)
# Out:
# array([[0.52103744, 0.0226581 , 0.54598853, ..., 0.91202749, 0.59846245,
#         0.41886396],
#        [0.64314449, 0.27257355, 0.61578329, ..., 0.63917526, 0.23358959,
#         0.22287813],
#        [0.60149557, 0.3902604 , 0.59574321, ..., 0.83505155, 0.40370589,
#         0.21343303],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.48728522, 0.12872068,
#         0.1519087 ],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.91065292, 0.49714173,
#         0.45231536],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.25744136,
#         0.10068215]])

# %%
x['area_mean'].describe()
# Out:
# count     569.000000
# mean      654.889104
# std       351.914129
# min       143.500000
# 25%       420.300000
# 50%       551.100000
# 75%       782.700000
# max      2501.000000
# Name: area_mean, dtype: float64

# %%
#for splitting the data into training set and test set
from sklearn import cross_validation, neighbors
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 42        19.070         24.81          128.30     1104.0          0.09081
# 263       15.610         19.38          100.00      758.6          0.07840
# 393       21.610         22.28          144.40     1407.0          0.11670
# 165       14.970         19.76           95.50      690.2          0.08421
# 269       10.710         20.39           69.50      344.9          0.10820
# 348       11.470         16.03           73.02      402.7          0.09076
# 542       14.740         25.42           94.70      668.6          0.08275
# 56        19.210         18.57          125.50     1152.0          0.10530
# 21         9.504         12.44           60.34      273.9          0.10240
# 432       20.180         19.54          133.80     1250.0          0.11330
# 493       12.460         12.83           78.83      477.3          0.07372
# ...

# %%
x_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 555       10.290         27.61           65.67      321.4          0.09030
# 251       11.500         18.45           73.28      407.4          0.09345
# 179       12.810         13.06           81.29      508.8          0.08739
# 75        16.070         19.65          104.10      817.7          0.09168
# 424        9.742         19.12           61.93      289.7          0.10750
# 74        12.310         16.52           79.19      470.9          0.09172
# 551       11.130         22.44           71.49      378.4          0.09566
# 382       12.050         22.72           78.75      447.8          0.06935
# 261       17.350         23.06          111.00      933.1          0.08662
# 506       12.220         20.04           79.47      453.1          0.10960
# 174       10.660         15.15           67.49      349.6          0.08792
# ...

# %%
y_train
# Out:
# 28     Malignant
# 382       Benign
# 310       Benign
# 93        Benign
# 216       Benign
# 523       Benign
# 565    Malignant
# 238       Benign
# 327       Benign
# 528       Benign
# 102       Benign
# 446    Malignant
# 178       Benign
# 224       Benign
# 525       Benign
# 405       Benign
# 142       Benign
# 78     Malignant
# 200       Benign
# 567    Malignant
# 100    Malignant
# 555       Benign
# 263    Malignant
# 218    Malignant
# 170       Benign
# 8      Malignant
# 385    Malignant
# 204       Benign
# 39     Malignant
# 196    Malignant
#          ...
# 373    Malignant
# 442       Benign
# 522       Benign
# 248       Benign
# 141    Malignant
# 173       Benign
# 98        Benign
# 558       Benign
# 254    Malignant
# 487    Malignant
# 438       Benign
# 484       Benign
# 540       Benign
# 190    Malignant
# 26     Malignant
# 435    Malignant
# 63        Benign
# 440       Benign
# 365    Malignant
# 474       Benign
# 553       Benign
# ...

# %%
y_test
# Out:
# 64     Malignant
# 19        Benign
# 482       Benign
# 366    Malignant
# 162    Malignant
# 161    Malignant
# 72     Malignant
# 2      Malignant
# 480       Benign
# 529       Benign
# 112       Benign
# 297    Malignant
# 262    Malignant
# 77     Malignant
# 272    Malignant
# 95     Malignant
# 252    Malignant
# 483       Benign
# 316       Benign
# 322       Benign
# 40     Malignant
# 406       Benign
# 293       Benign
# 533    Malignant
# 345       Benign
# 99     Malignant
# 75     Malignant
# 531       Benign
# 289       Benign
# 27     Malignant
#          ...
# 467       Benign
# 491       Benign
# 226       Benign
# 120       Benign
# 139       Benign
# 334       Benign
# 235       Benign
# 282    Malignant
# 118    Malignant
# 398       Benign
# 229    Malignant
# 397       Benign
# 393    Malignant
# 267       Benign
# 58        Benign
# 466       Benign
# 449    Malignant
# 526       Benign
# 339    Malignant
# 67        Benign
# 30     Malignant
# ...

# %%
#building KNN classifier
clf=neighbors.KNeighborsClassifier()
clf.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Benign', 'Malignant', 'Malignant', 'Benign',
# ...

# %%
from sklearn.metrics import confusion_matrix
clf_cm_test = confusion_matrix(y_test,y_pred)
clf_cm_test
# Out:
# array([[63,  2],
#        [ 7, 42]], dtype=int64)

# %%
y_test.value_counts()
# Out:
# Benign       65
# Malignant    49
# Name: diagnosis, dtype: int64

# %%
#To get the accuracy of the model
accuracy = clf.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.9210526315789473

# %%
example_measures=np.array([15.44,12.54,150.9,998,0.2345,0.3452,0.2891,0.1234,0.3421,0.6879,2.076,0.8079,
                           7.274,168.7,0.009786,0.03804,0.04327,0.02785,0.02002,0.007621,28.75,16.44,192.7,
                           2025,0.1723,0.7752,0.7121,0.3421,0.4802,0.1278])
example_measures=example_measures.reshape(1,-1)

# %%
prediction=clf.predict(example_measures)
print(prediction)
# Out:
# ['Malignant']

# %%
#Model Building for SVM classifier
from sklearn.svm import SVC
sc=SVC(kernel='rbf')
sc_classifier=sc.fit(x_train,y_train)

# %%
#Prediction for SVM classifier
svc_y_test=sc_classifier.predict(x_test)
print(svc_y_test)
# Out:
# ['Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
# ...

# %%
svc_y_train=sc_classifier.predict(x_train)
print(svc_y_train)
# Out:
# ['Malignant' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Malignant'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Malignant' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Malignant' 'Benign' 'Malignant' 'Malignant'
#  'Benign' 'Malignant' 'Malignant' 'Benign' 'Malignant' 'Malignant'
#  'Benign' 'Malignant' 'Malignant' 'Benign' 'Malignant' 'Malignant'
#  'Benign' 'Malignant' 'Malignant' 'Malignant' 'Benign' 'Benign' 'Benign'
#  'Malignant' 'Malignant' 'Benign' 'Benign' 'Benign' 'Malignant' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Malignant' 'Malignant' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Malignant' 'Malignant' 'Benign'
#  'Benign' 'Benign' 'Malignant' 'Benign' 'Benign' 'Benign' 'Malignant'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Malignant' 'Malignant'
#  'Benign' 'Benign' 'Malignant' 'Benign' 'Benign' 'Benign' 'Malignant'
#  'Malignant' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Malignant'
# ...

# %%
svc_y_test=sc_classifier.predict(x_test)
print(svc_y_test)
# Out:
# ['Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
# ...

# %%
#confusion matrix on test
from sklearn.metrics import confusion_matrix
svc_cm_test=confusion_matrix(y_test,svc_y_test)
svc_cm_test
# Out:
# array([[65,  0],
#        [49,  0]], dtype=int64)

# %%
#confusion matrix on train
svc_cm_train=confusion_matrix(y_train,svc_y_train)
svc_cm_train
# Out:
# array([[174, 118],
#        [112,  51]], dtype=int64)

# %%
#accuracy score for SVM
from sklearn.metrics import accuracy_score
svc_acc_test=accuracy_score(y_test,svc_y_test)
svc_acc_test
# Out:
# 0.5701754385964912

# %%
#precision for SVM model - test data
from sklearn.metrics import precision_score
svc_precision_test=precision_score(y_test,svc_y_test,average='weighted')
print(svc_precision_test)
# Out:
# 0.32510003077870114
# C:\Users\mouni\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#precision for SVM model - train data
svc_precision_train=precision_score(y_train,svc_y_train,average='weighted')
print(svc_precision_train)
# Out:
# 0.4985487884896169

# %%
#Linear Regression
from sklearn.linear_model.logistic import LogisticRegression
cls=LogisticRegression(random_state=0)
lr_cls=cls.fit(x_train,y_train)

# %%
#prediction for linear regression
lr_y_test=lr_cls.predict(x_test)
lr_y_test
# Out:
# array(['Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Malignant', 'Benign',
# ...

# %%
lr_y_train=lr_cls.predict(x_train)
lr_y_train
# Out:
# array(['Malignant', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign',
# ...

# %%
#confusion matrix for regression model
from sklearn.metrics import confusion_matrix
lr_cm_test=confusion_matrix(y_test,lr_y_test)
lr_cm_test
# Out:
# array([[64,  1],
#        [ 4, 45]], dtype=int64)

# %%
#accuracy for regression model
from sklearn.metrics import accuracy_score
lr_accu_test=accuracy_score(y_test,lr_y_test)
lr_accu_test
# Out:
# 0.956140350877193

# %%
lr_accu_train=accuracy_score(y_train,lr_y_train)
lr_accu_train
# Out:
# 0.9538461538461539

# %%
#precision for regression model - test data
from sklearn.metrics import precision_score
lr_precision_test=precision_score(y_test,lr_y_test,average='weighted')
print(lr_precision_test)
# Out:
# 0.9571162561134293

# %%
#precision for regression model - train data
lr_precision_train=precision_score(y_train,lr_y_train,average='weighted')
print(lr_precision_train)
# Out:
# 0.9537707487074575

# %%
#Building model for DecisoinTreeClassifier
from sklearn.tree import DecisionTreeClassifier
dtc_clf=DecisionTreeClassifier()
dtc_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#Prediction for Decision Tree Classifier
dtc_y_train=dtc_clf.predict(x_train)
dtc_y_train
# Out:
# array(['Malignant', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
# ...

# %%
dtc_y_test=dtc_clf.predict(x_test)
dtc_y_test
# Out:
# array(['Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Malignant', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Malignant',
#        'Malignant', 'Malignant', 'Malignant', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
# ...

# %%
#Confusion Matrix for Decision Tree Classifier
from sklearn.metrics import confusion_matrix
dtc_cm_test=confusion_matrix(y_test,dtc_y_test)
dtc_cm_test
# Out:
# array([[62,  3],
#        [ 2, 47]], dtype=int64)

# %%
#accuracy score for Decision Tree Classifier
from sklearn.metrics import accuracy_score
dtc_accu_test=accuracy_score(y_test,dtc_y_test)
dtc_accu_test
# Out:
# 0.956140350877193

# %%
dtc_accu_train=accuracy_score(y_train,dtc_y_train)
dtc_accu_train
# Out:
# 1.0

# %%
#precision score for the model
from sklearn.metrics import precision_score
dtc_precision_test=precision_score(y_test,dtc_y_test,average='weighted')
print(dtc_precision_test)
# Out:
# 0.9563925438596491

# %%
dtc_precision_train=precision_score(y_train,dtc_y_train,average='weighted')
print(dtc_precision_train)
# Out:
# 1.0

# %%
#Building model for random forest
from sklearn.ensemble import RandomForestClassifier
rmf=RandomForestClassifier(max_depth=3,random_state=0)
rf_classi=rmf.fit(x_train,y_train)

# %%
#Prediction for random forest
rmf_y_train=rf_classi.predict(x_train)
rmf_y_train
# Out:
# array(['Malignant', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign',
# ...

# %%
rmf_y_test=rf_classi.predict(x_test)
rmf_y_test
# Out:
# array(['Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Malignant', 'Benign',
# ...

# %%
#confusion matrix for random forest
from sklearn.metrics import confusion_matrix
rmf_cm_test=confusion_matrix(y_test,rmf_y_test)
rmf_cm_test
# Out:
# array([[65,  0],
#        [ 4, 45]], dtype=int64)

# %%
#accuracy for random forest
from sklearn.metrics import accuracy_score
rmf_accu_test=accuracy_score(y_test,rmf_y_test)
rmf_accu_test
# Out:
# 0.9649122807017544

# %%
rmf_accu_train=accuracy_score(y_train,rmf_y_train)
rmf_accu_train
# Out:
# 0.9692307692307692

# %%
#Precision for random forest
from sklearn.metrics import precision_score
rmf_prec_test=precision_score(y_test,rmf_y_test,average='weighted')
rmf_prec_test
# Out:
# 0.9669463513857106

# %%
rmf_prec_train=precision_score(y_train,rmf_y_train,average='weighted')
rmf_prec_train
# Out:
# 0.9701839290023326

# %%
#Recall values for random forest
from sklearn.metrics import recall_score
rf_recall_test=recall_score(y_test,rmf_y_test,average='weighted')
rf_recall_test
# Out:
# 0.9649122807017544

# %%
rf_recall_train=recall_score(y_train,rmf_y_train,average='weighted')
rf_recall_train
# Out:
# 0.9692307692307692

# %%
#building model for adaptive selection
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier
#selecting some item is called seed. making the algo behave the way we want is done by seed
seed=7
#since it is recursive model we give number of trees here
num_trees=30
kfold=model_selection.KFold(n_splits=10,random_state=seed)
model=AdaBoostClassifier(n_estimators=num_trees,random_state=seed)
results=model_selection.cross_val_score(model,x_train,y_train,cv=kfold)

# %%
print(results)
# Out:
# [0.93478261 0.95652174 0.97826087 0.89130435 0.95652174 0.97777778
#  0.95555556 0.97777778 0.95555556 0.88888889]

# %%
print(results.mean())
# Out:
# 0.9472946859903383
